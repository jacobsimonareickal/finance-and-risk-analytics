# %% [markdown]
# # <center> Capstone Project - Finance and Risk Analytics</center>
# ### <center> Submitted by: Jacob Simon Areickal</center>
# ### <center> Submitted on: 16-May-2023</center>

# %% [markdown]
# ### Business Case
#
# In the recent past, the industry of wealth management has seen a lot of growth. Individuals and businesses actively seek maximum returns. However, in many cases, they lack either the skills to identify the right investment opportunities or the time to find such opportunities. This challenge gave rise to the dedicated individuals who perform this task on behalf of the investors for a commission: portfolio managers.
#
# A portfolio manager makes investment decisions and carries out other related activities on behalf of vested investors. They work with a team of analysts and researchers, and their main objective is to realize the needs of the investor and suggest a suitable portfolio that meets all the expectations. They are responsible for establishing the best investment strategy and selecting appropriate investments with the right allocations. However, in doing so, they face a lot of competition in the form of other portfolio managers and rival firms. Therefore, the portfolio manager has to use the available resources to provide the best solution to the investor.
#
#  Consider yourself working for an associate at an investment firm that manages accounts for private clients. Your role requires you to analyze a portfolio of stocks to provide consultation on investment management based on client requirements.
#
# __Following points summarise the expected tasks to be performed for the capstone project:__
#
# 1. You must use the elements of technical analysis to understand the trend of the underlying stocks. The metrics associated with risk and returns must help you realise whether the security meets the criteria of your investor’s financial goals.
# 2. You must use the metrics and the visualisations to compare the performance of the available securities against each other, and also against the market index, S&P500.
# 3. The findings should be aligned with the investor persona to select the appropriate stocks for the portfolio.
# 4. After the selection of stocks, the portfolio must be validated using the active investment strategy to estimate the prices in future. You must check if the portfolio has the potential to fulfil the financial goals set by the investor.

# %% [markdown]
# __The entire capstone can be divided into the following aspects:__
#
# 1. Preliminary Steps - Data loading
# 2. Data Exploration
# 3. Stock Analysis and Portfolio Management and Reporting the insights

# %% [markdown]
# ## <center> Task 1: Preliminary Steps</center>
#
# Under preliminary steps, data is expected to be loaed into the working environment (Python). The entire data must be merged into a single dataframe with only the required columns. Most importantly, you must ensure that you can identify the company and the industry from the collated data for company-specific and industry analysis.
#
# __To make the task easier to accomplish, I have divided the task into 3 subtasks:__
# 1. Data Loading
# 2. Data Analysis
# 3. Data Cleaning and Handling of Null Values
# 4. Dataframe Merging

# %% [markdown]
# ### Sub-Task 1: Data Loading
#
# I have created a folder called Dataset which contains sub folders for the different domains. The Dataset folder also contains S&P500 index prices data as well. The directory structure is as given in the image below:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's first import the required libraries required for the project as below:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# I set a global style for seaborn as below.

# %%
sns.set_style(style='darkgrid')

# %% [markdown]
# Let's start by reading Aviation domain data to dataframes

# %%
## Dataframe of stock prices for company 'AAL'
AAL = pd.read_csv('./Dataset/Aviation/AAL.csv', header='infer')

## Dataframe of stock prices for company 'ALGT'
ALGT = pd.read_csv('./Dataset/Aviation/ALGT.csv', header='infer')

## Dataframe of stock prices for company 'ALK'
ALK = pd.read_csv('./Dataset/Aviation/ALK.csv', header='infer')

## Dataframe of stock prices for company 'DAL'
DAL = pd.read_csv('./Dataset/Aviation/DAL.csv', header='infer')

## Dataframe of stock prices for company 'HA'
HA = pd.read_csv('./Dataset/Aviation/HA.csv', header='infer')

## Dataframe of stock prices for company 'LUV'
LUV = pd.read_csv('./Dataset/Aviation/LUV.csv', header='infer')

# %% [markdown]
# Now let's read the Finance domain data to Pandas dataframes

# %%
## Dataframe of stock prices for company 'BCS'
BCS = pd.read_csv('./Dataset/Finance/BCS.csv', header='infer')

## Dataframe of stock prices for company 'CS'
CS = pd.read_csv('./Dataset/Finance/CS.csv', header='infer')

## Dataframe of stock prices for company 'DB'
DB = pd.read_csv('./Dataset/Finance/DB.csv', header='infer')

## Dataframe of stock prices for company 'GS'
GS = pd.read_csv('./Dataset/Finance/GS.csv', header='infer')

## Dataframe of stock prices for company 'MS'
MS = pd.read_csv('./Dataset/Finance/MS.csv', header='infer')

## Dataframe of stock prices for company 'WFC'
WFC = pd.read_csv('./Dataset/Finance/WFC.csv', header='infer')

# %% [markdown]
# Now do the same for Pharma Healthcare domain

# %%
## Dataframe of stock prices for company 'BHC'
BHC = pd.read_csv('./Dataset/Pharma_Healthcare/BHC.csv', header='infer')

## Dataframe of stock prices for company 'JNJ'
JNJ = pd.read_csv('./Dataset/Pharma_Healthcare/JNJ.csv', header='infer')

## Dataframe of stock prices for company 'MRK'
MRK = pd.read_csv('./Dataset/Pharma_Healthcare/MRK.csv', header='infer')

## Dataframe of stock prices for company 'PFE'
PFE = pd.read_csv('./Dataset/Pharma_Healthcare/PFE.csv', header='infer')

## Dataframe of stock prices for company 'RHHBY'
RHHBY = pd.read_csv('./Dataset/Pharma_Healthcare/RHHBY.csv', header='infer')

## Dataframe of stock prices for company 'UNH'
UNH = pd.read_csv('./Dataset/Pharma_Healthcare/UNH.csv', header='infer')

# %% [markdown]
# Let's proceed to read the Technology domain data as well to Pandas dataframes

# %%
## Dataframe of stock prices for company 'AAPL'
AAPL = pd.read_csv('./Dataset/Technology/AAPL.csv', header='infer')

## Dataframe of stock prices for company 'AMZN'
AMZN = pd.read_csv('./Dataset/Technology/AMZN.csv', header='infer')

## Dataframe of stock prices for company 'FB'
FB = pd.read_csv('./Dataset/Technology/FB.csv', header='infer')

## Dataframe of stock prices for company 'GOOG'
GOOG = pd.read_csv('./Dataset/Technology/GOOG.csv', header='infer')

## Dataframe of stock prices for company 'IBM'
IBM = pd.read_csv('./Dataset/Technology/IBM.csv', header='infer')

## Dataframe of stock prices for company 'MSFT'
MSFT = pd.read_csv('./Dataset/Technology/MSFT.csv', header='infer')

# %% [markdown]
# Now I will read the SP&P500 into a Pandas dataframe

# %%
SP500 = pd.read_csv('./Dataset/S&P500.csv', header='infer')

# %% [markdown]
# Now that I have read all our data to Pandas dataframe, let me assert that all loaded dataframes are not empty to proceed with our analysis

# %%
try:
    ## Aviation Dataframes
    assert AAL.empty == False
    assert ALGT.empty == False
    assert ALK.empty == False
    assert DAL.empty == False
    assert HA.empty == False
    assert LUV.empty == False

    ## Finance Dataframes
    assert BCS.empty == False
    assert CS.empty == False
    assert DB.empty == False
    assert GS.empty == False
    assert MS.empty == False
    assert WFC.empty == False

    ## Pharma Healthcare Dataframes
    assert BHC.empty == False
    assert JNJ.empty == False
    assert MRK.empty == False
    assert PFE.empty == False
    assert RHHBY.empty == False
    assert UNH.empty == False

    ## Technology Dataframes
    assert AAPL.empty == False
    assert AMZN.empty == False
    assert FB.empty == False
    assert GOOG.empty == False
    assert IBM.empty == False
    assert MSFT.empty == False

    ## SP&P 500 Dataframe
    assert SP500.empty == False
    
    print('All stock price dataframes are non empty. Assertion is successful')

except AssertionError as e:
    print(f'Assertion failed. Please check if all dataframes are non empty')
# Out:
# All stock price dataframes are non empty. Assertion is successful

# %% [markdown]
# Now that we have loaded all our data to Pandas dataframes and also asserted that all the dataframes contains data, we have successfully completed the first subtask (Data Loading). Now let's proceed to the new sub-task.

# %% [markdown]
# ### Sub-Task 2: Data Analysis
# _Here I will be exploring the dataframes and their schemas. This will help me track whether the column datatypes have been inferred as the correct datatype by Pandas. To do that, I will create an array/list of the the dataframes and then iterate over each dataframe. This technique will help reduce lines of code and make code easier to understand and more generalisable._

# %%
stocks_dataframes_list = [AAL, ALGT, ALK, DAL, HA, LUV, BCS, CS, DB, GS, MS, 
                          WFC, BHC, JNJ, MRK, PFE, RHHBY, UNH, AAPL, AMZN, 
                          FB, GOOG, IBM, MSFT, SP500]

## The below is a dictionary mapping with key as the dataframe name and value as the Pandas Dataframe object. 
## I use the below dictionary mapping to get the dataframe name from the dataframe object

dataframe_mapping = {
    'AAL':AAL,
    'ALGT':ALGT,
    'ALK':ALK,
    'DAL':DAL,
    'HA':HA,
    'LUV':LUV,
    'BCS':BCS,
    'CS':CS,
    'DB':DB,
    'GS':GS,
    'MS':MS,
    'WFC':WFC,
    'BHC':BHC,
    'JNJ':JNJ,
    'MRK':MRK,
    'PFE':PFE,
    'RHHBY':RHHBY,
    'UNH':UNH,
    'AAPL':AAPL,
    'AMZN':AMZN,
    'FB':FB,
    'GOOG':GOOG,
    'IBM':IBM,
    'MSFT':MSFT,
    'SP500':SP500,
}

# %% [markdown]
# I define a helper function as below to get dataframe name for the given dataframe object

# %%
## The below helper function returns the dataframe name for the given dataframe object using the dataframe_mapping dictionary
def get_name_from_dataframe(val:pd.DataFrame, dataframe_mapping:dict) -> str:
    '''
    val: The dataframe object for which you require the name
    dataframe_mapping: Dictionary mapping with key as the dataframe name and value as the Pandas Dataframe object
    
    Returns: Dataframe Name (str)
    '''
    for key, value in dataframe_mapping.items():
        if val is value:
            return key
    return "DataFrame does not exist!!!"

# %% [markdown]
# __Let's first check the schemas of all the dataframes__

# %%
for stock in stocks_dataframes_list:
    print(f'DataFrame "{get_name_from_dataframe(stock, dataframe_mapping)}"')
    print(stock.info())
    print('='*60)
# Out:
# DataFrame "AAL"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 137.8+ KB
# None
# ============================================================
# DataFrame "ALGT"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "ALK"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "DAL"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "HA"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "LUV"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "BCS"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2712 entries, 0 to 2711
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2705 non-null   object
#  1   Open       2705 non-null   float64
#  2   High       2705 non-null   float64
#  3   Low        2705 non-null   float64
#  4   Close      2705 non-null   float64
#  5   Adj Close  2705 non-null   float64
#  6   Volume     2705 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 148.4+ KB
# None
# ============================================================
# DataFrame "CS"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2712 entries, 0 to 2711
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2705 non-null   object
#  1   Open       2705 non-null   float64
#  2   High       2705 non-null   float64
#  3   Low        2705 non-null   float64
#  4   Close      2705 non-null   float64
#  5   Adj Close  2705 non-null   float64
#  6   Volume     2705 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 148.4+ KB
# None
# ============================================================
# DataFrame "DB"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2712 entries, 0 to 2711
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2705 non-null   object
#  1   Open       2705 non-null   float64
#  2   High       2705 non-null   float64
#  3   Low        2705 non-null   float64
#  4   Close      2705 non-null   float64
#  5   Adj Close  2705 non-null   float64
#  6   Volume     2705 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 148.4+ KB
# None
# ============================================================
# DataFrame "GS"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2712 entries, 0 to 2711
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2705 non-null   object
#  1   Open       2705 non-null   float64
#  2   High       2705 non-null   float64
#  3   Low        2705 non-null   float64
#  4   Close      2705 non-null   float64
#  5   Adj Close  2705 non-null   float64
#  6   Volume     2705 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 148.4+ KB
# None
# ============================================================
# DataFrame "MS"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2712 entries, 0 to 2711
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2705 non-null   object
#  1   Open       2705 non-null   float64
#  2   High       2705 non-null   float64
#  3   Low        2705 non-null   float64
#  4   Close      2705 non-null   float64
#  5   Adj Close  2705 non-null   float64
#  6   Volume     2705 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 148.4+ KB
# None
# ============================================================
# DataFrame "WFC"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2712 entries, 0 to 2711
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2705 non-null   object
#  1   Open       2705 non-null   float64
#  2   High       2705 non-null   float64
#  3   Low        2705 non-null   float64
#  4   Close      2705 non-null   float64
#  5   Adj Close  2705 non-null   float64
#  6   Volume     2705 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 148.4+ KB
# None
# ============================================================
# DataFrame "BHC"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2525 entries, 0 to 2524
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "JNJ"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2525 entries, 0 to 2524
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "MRK"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2525 entries, 0 to 2524
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "PFE"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2525 entries, 0 to 2524
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "RHHBY"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2525 entries, 0 to 2524
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "UNH"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2525 entries, 0 to 2524
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "AAPL"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 137.8+ KB
# None
# ============================================================
# DataFrame "AMZN"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "FB"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2113 entries, 0 to 2112
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2106 non-null   object
#  1   Open       2106 non-null   float64
#  2   High       2106 non-null   float64
#  3   Low        2106 non-null   float64
#  4   Close      2106 non-null   float64
#  5   Adj Close  2106 non-null   float64
#  6   Volume     2106 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 115.7+ KB
# None
# ============================================================
# DataFrame "GOOG"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "IBM"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "MSFT"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2524 entries, 0 to 2523
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 138.2+ KB
# None
# ============================================================
# DataFrame "SP500"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2517 entries, 0 to 2516
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2517 non-null   object
#  1   Open       2517 non-null   float64
#  2   High       2517 non-null   float64
#  3   Low        2517 non-null   float64
#  4   Close      2517 non-null   float64
#  5   Adj Close  2517 non-null   float64
#  6   Volume     2517 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 137.8+ KB
# None
# ============================================================

# %% [markdown]
# __Now we need to check the datatypes of all the columns of all the dataframes. Of course we can check them one by one but a more faster and easier way would be to iterate over all the dataframes and check the columns and their datatypes. If the datatypes do not match, then we print an error.__

# %%
## The below is the dictionary with columns as keys and expected datatype/datatypes as values

expected_datatypes = {
    'Date': 'datetime64[ns]',
    'Open': 'int64/float64',
    'High': 'int64/float64',
    'Low': 'int64/float64',
    'Close': 'int64/float64',
    'Adj Close': 'int64/float64',
    'Volume': 'int64/float64'
}

## Below I define a function that takes in a list of dataframes and checks the datatypes of all the columns. 
## It returns an error message if the datatypes does not match

def validate_columns(stocks_dataframes_list:list[pd.DataFrame], expected_datatypes:dict) -> None:
    '''
    stocks_dataframes_list: List/Array of Dataframe objects
    expected_datatypes: Expected Datatypes of the columns
    
    Returns: None
    '''
    is_valid = True
    mismatch_counter = 0
    for stock in stocks_dataframes_list:
        for col in stock.columns:
            if str(stock.dtypes[col].name) not in expected_datatypes[col]:
                print(f'Column "{col}" in Dataframe "{get_name_from_dataframe(stock, dataframe_mapping)}" does not match the expected datatype. Expected datatype is {expected_datatypes[col]} but the current datatype is {stock.dtypes[col]}')
                mismatch_counter+=1
                is_valid = False
    if is_valid:
        print('Validation successful. All columns of all dataframes have the expected datatypes.')
    else:
        print(f'There are a total of {mismatch_counter} mismatches in the datatypes of the columns. Please cast to appropriate datatypes and try again..')


## Calling the defined function to validate the columns
validate_columns(stocks_dataframes_list, expected_datatypes)
# Out:
# Column "Date" in Dataframe "AAL" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "ALGT" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "ALK" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "DAL" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "HA" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "LUV" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "BCS" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "CS" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "DB" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "GS" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "MS" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "WFC" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "BHC" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "JNJ" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "MRK" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "PFE" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "RHHBY" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "UNH" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "AAPL" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "AMZN" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "FB" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "GOOG" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "IBM" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "MSFT" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# Column "Date" in Dataframe "SP500" does not match the expected datatype. Expected datatype is datetime64[ns] but the current datatype is object
# There are a total of 25 mismatches in the datatypes of the columns. Please cast to appropriate datatypes and try again..

# %% [markdown]
# As we can see, the Date column in all the dataframes are of type __object__ but the expected type is __datetime__. So let's cast the Date columns and run the function again to verify.

# %%
def cast_col_to_datatype(stocks_dataframes_list:list[pd.DataFrame], col:str, datatype:str) -> None:
    '''
    This helper function is used to convert a given column to the desired datatype
    
    stocks_dataframes_list: List of DataFrame objects
    col: Column name for which you want to cast
    datatype: Datatype you want to cast that input col to
    
    Return: None
    '''
    for stock in stocks_dataframes_list:
        stock[col] = stock[col].astype(datatype)
        print(f'Column {col} of DataFrame {get_name_from_dataframe(stock, dataframe_mapping)} has been cast to {datatype}')

cast_col_to_datatype(stocks_dataframes_list, 'Date', 'datetime64[ns]')
# Out:
# Column Date of DataFrame AAL has been cast to datetime64[ns]
# Column Date of DataFrame ALGT has been cast to datetime64[ns]
# Column Date of DataFrame ALK has been cast to datetime64[ns]
# Column Date of DataFrame DAL has been cast to datetime64[ns]
# Column Date of DataFrame HA has been cast to datetime64[ns]
# Column Date of DataFrame LUV has been cast to datetime64[ns]
# Column Date of DataFrame BCS has been cast to datetime64[ns]
# Column Date of DataFrame CS has been cast to datetime64[ns]
# Column Date of DataFrame DB has been cast to datetime64[ns]
# Column Date of DataFrame GS has been cast to datetime64[ns]
# Column Date of DataFrame MS has been cast to datetime64[ns]
# Column Date of DataFrame WFC has been cast to datetime64[ns]
# Column Date of DataFrame BHC has been cast to datetime64[ns]
# Column Date of DataFrame JNJ has been cast to datetime64[ns]
# Column Date of DataFrame MRK has been cast to datetime64[ns]
# Column Date of DataFrame PFE has been cast to datetime64[ns]
# Column Date of DataFrame RHHBY has been cast to datetime64[ns]
# Column Date of DataFrame UNH has been cast to datetime64[ns]
# Column Date of DataFrame AAPL has been cast to datetime64[ns]
# Column Date of DataFrame AMZN has been cast to datetime64[ns]
# Column Date of DataFrame FB has been cast to datetime64[ns]
# Column Date of DataFrame GOOG has been cast to datetime64[ns]
# Column Date of DataFrame IBM has been cast to datetime64[ns]
# Column Date of DataFrame MSFT has been cast to datetime64[ns]
# Column Date of DataFrame SP500 has been cast to datetime64[ns]

# %% [markdown]
# __Now that we have cast the Date column to date time, let's run the validate_columns function again to validate the datatypes of all the columns__

# %%
validate_columns(stocks_dataframes_list, expected_datatypes)
# Out:
# Validation successful. All columns of all dataframes have the expected datatypes.

# %% [markdown]
# __As we can see from above, we called the defined function to validate all the datatypes of the columns. We got a successfull validation output and we can proceed further with our data exploration__

# %% [markdown]
# Now I will check the number of rows and columns of each dataframe and print it. I create a function for this as well to allow code reusability and generalizability.

# %%
def get_rows_columns(stocks_dataframes_list:list[pd.DataFrame], dataframe_mapping:dict) -> None:
    '''
    stocks_dataframes_list: List/Array of Dataframe objects
    dataframe_mapping: A dictionary mapping of dataframe name and the corresponding dataframe object
    
    Returns: None
    '''
    for stock in stocks_dataframes_list:
        print(f'There are {stock.shape[0]} rows and {stock.shape[1]} columns in the dataframe "{get_name_from_dataframe(stock, dataframe_mapping)}"')

get_rows_columns(stocks_dataframes_list, dataframe_mapping)
# Out:
# There are 2517 rows and 7 columns in the dataframe "AAL"
# There are 2524 rows and 7 columns in the dataframe "ALGT"
# There are 2524 rows and 7 columns in the dataframe "ALK"
# There are 2524 rows and 7 columns in the dataframe "DAL"
# There are 2524 rows and 7 columns in the dataframe "HA"
# There are 2524 rows and 7 columns in the dataframe "LUV"
# There are 2712 rows and 7 columns in the dataframe "BCS"
# There are 2712 rows and 7 columns in the dataframe "CS"
# There are 2712 rows and 7 columns in the dataframe "DB"
# There are 2712 rows and 7 columns in the dataframe "GS"
# There are 2712 rows and 7 columns in the dataframe "MS"
# There are 2712 rows and 7 columns in the dataframe "WFC"
# There are 2525 rows and 7 columns in the dataframe "BHC"
# There are 2525 rows and 7 columns in the dataframe "JNJ"
# There are 2525 rows and 7 columns in the dataframe "MRK"
# There are 2525 rows and 7 columns in the dataframe "PFE"
# There are 2525 rows and 7 columns in the dataframe "RHHBY"
# There are 2525 rows and 7 columns in the dataframe "UNH"
# There are 2517 rows and 7 columns in the dataframe "AAPL"
# There are 2524 rows and 7 columns in the dataframe "AMZN"
# There are 2113 rows and 7 columns in the dataframe "FB"
# There are 2524 rows and 7 columns in the dataframe "GOOG"
# There are 2524 rows and 7 columns in the dataframe "IBM"
# There are 2524 rows and 7 columns in the dataframe "MSFT"
# There are 2517 rows and 7 columns in the dataframe "SP500"

# %% [markdown]
# As we can see from above, most of the dataframes have approximate same number of rows and same number of columns.

# %% [markdown]
# To get a better grasp on our data, I will print the first 3 rows of all the stock dataframes. This will help us to check how the data looks like and check for any column inconsistency we may have missed to check

# %%
for stock in stocks_dataframes_list:
    print(f'Dataframe "{get_name_from_dataframe(stock, dataframe_mapping)}"')
    print(stock.head(3))
    print('='*100)
# Out:
# Dataframe "AAL"
#         Date  Open  High   Low  Close  Adj Close   Volume
# 0 2010-01-10  9.29  9.39  9.21   9.29   8.758067  3603800
# 1 2010-04-10  9.24  9.48  9.05   9.12   8.597802  3856800
# 2 2010-05-10  9.27  9.35  9.15   9.23   8.701504  3896600
# ====================================================================================================
# Dataframe "ALGT"
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2010-01-10  42.779999  43.259998  41.869999  43.230000  36.766212  159100.0
# 1 2010-04-10  43.250000  43.330002  41.310001  41.590000  35.371429  189700.0
# 2 2010-05-10  41.779999  42.130001  41.299999  42.099998  35.805168  175000.0
# ====================================================================================================
# Dataframe "ALK"
#         Date     Open     High      Low    Close  Adj Close     Volume
# 0 2010-01-10  12.9325  12.9625  12.3675  12.4475  10.972344  1663600.0
# 1 2010-04-10  12.4300  12.5900  11.9975  12.1425  10.703489  1512400.0
# 2 2010-05-10  12.2600  12.2850  11.9450  12.2150  10.767396  2567200.0
# ====================================================================================================
# Dataframe "DAL"
#         Date   Open   High    Low  Close  Adj Close      Volume
# 0 2010-01-10  11.75  12.01  11.71  12.01  10.668407   9094900.0
# 1 2010-04-10  11.70  12.01  11.45  11.51  10.224259   7916400.0
# 2 2010-05-10  11.57  11.87  11.45  11.83  10.508514  12624100.0
# ====================================================================================================
# Dataframe "HA"
#         Date  Open  High   Low  Close  Adj Close    Volume
# 0 2010-01-10  6.02  6.05  5.88   5.96   5.742526  645400.0
# 1 2010-04-10  5.96  6.00  5.73   5.75   5.540189  618900.0
# 2 2010-05-10  5.82  5.93  5.77   5.85   5.636539  534800.0
# ====================================================================================================
# Dataframe "LUV"
#         Date   Open   High    Low  Close  Adj Close     Volume
# 0 2010-01-10  13.23  13.24  12.92  12.94  12.018754  5722500.0
# 1 2010-04-10  12.92  13.09  12.62  12.82  11.907295  6537700.0
# 2 2010-05-10  12.97  13.16  12.94  13.02  12.093060  8060000.0
# ====================================================================================================
# Dataframe "BCS"
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2010-04-01  16.709677  16.930876  16.663595  16.894009  12.665321  2144300.0
# 1 2010-05-01  17.631336  17.852535  17.520737  17.824884  13.363193  2710600.0
# 2 2010-06-01  17.797235  18.202765  17.695852  18.129032  13.591214  2124100.0
# ====================================================================================================
# Dataframe "CS"
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2010-04-01  49.902344  51.035156  49.765625  50.771484  34.852165  734200.0
# 1 2010-05-01  51.250000  51.318359  50.644531  51.191406  35.140423  447700.0
# 2 2010-06-01  50.224609  50.917969  49.951172  50.478516  34.651054  751200.0
# ====================================================================================================
# Dataframe "DB"
#         Date       Open       High        Low      Close  Adj Close    Volume
# 0 2010-04-01  69.103050  70.162216  68.893127  69.875954  59.037861  469500.0
# 1 2010-05-01  71.412216  71.698471  70.610687  71.211830  60.166534  503300.0
# 2 2010-06-01  69.847328  70.543892  69.494278  69.980919  59.126545  495000.0
# ====================================================================================================
# Dataframe "GS"
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2010-04-01  170.050003  174.250000  169.509995  173.080002  147.920776
# 1 2010-05-01  173.000000  176.259995  172.570007  176.139999  150.535919
# 2 2010-06-01  175.380005  175.380005  173.759995  174.259995  148.929138
#
#        Volume
# 0   9135000.0
# 1  11659400.0
# 2   7381100.0
# ====================================================================================================
# Dataframe "MS"
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2010-04-01  30.700001  31.969999  30.629999  30.910000  25.759523
# 1 2010-05-01  31.010000  32.130001  30.930000  32.040001  26.701244
# 2 2010-06-01  31.969999  32.590000  31.790001  32.450001  27.042919
#
#        Volume
# 0  20371000.0
# 1  22523400.0
# 2  17028500.0
# ====================================================================================================
# Dataframe "WFC"
#         Date       Open   High        Low      Close  Adj Close      Volume
# 0 2010-04-01  27.020000  27.48  26.820000  27.320000  20.318752  39335700.0
# 1 2010-05-01  27.270000  28.24  27.240000  28.070000  20.876556  55416000.0
# 2 2010-06-01  28.030001  28.33  27.790001  28.110001  20.906300  33237000.0
# ====================================================================================================
# Dataframe "BHC"
#         Date       Open       High    Low      Close  Adj Close     Volume
# 0 2010-01-10  25.120001  25.879999  25.10  25.750000  24.757708  5778700.0
# 1 2010-04-10  25.750000  25.990000  25.59  25.870001  24.873083  4187200.0
# 2 2010-05-10  26.040001  26.330000  25.83  26.299999  25.286512  4610300.0
# ====================================================================================================
# Dataframe "JNJ"
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2010-01-10  62.090000  62.250000  61.570000  61.750000  45.970119
# 1 2010-04-10  61.540001  61.980000  61.299999  61.669998  45.910553
# 2 2010-05-10  62.080002  62.939999  62.009998  62.799999  46.751797
#
#        Volume
# 0   9773200.0
# 1   8703600.0
# 2  12439400.0
# ====================================================================================================
# Dataframe "MRK"
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2010-01-10  36.759998  36.840000  36.349998  36.599998  26.052284
# 1 2010-04-10  36.490002  36.750000  36.290001  36.520000  25.995331
# 2 2010-05-10  36.860001  37.150002  36.700001  37.020000  26.351234
#
#        Volume
# 0  11741900.0
# 1   9234900.0
# 2  10669200.0
# ====================================================================================================
# Dataframe "PFE"
#         Date       Open       High        Low  Close  Adj Close      Volume
# 0 2010-01-10  17.250000  17.290001  17.110001  17.18  11.900640  35520800.0
# 1 2010-04-10  17.100000  17.200001  16.860001  16.90  11.706684  40665800.0
# 2 2010-05-10  17.110001  17.250000  17.059999  17.23  11.935278  44694000.0
# ====================================================================================================
# Dataframe "RHHBY"
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2010-01-10  17.200001  17.450001  17.190001  17.389999  10.770474  1405600.0
# 1 2010-04-10  17.305000  17.344999  17.225000  17.275000  10.699248   453600.0
# 2 2010-05-10  17.575001  17.815001  17.549999  17.799999  11.024405  1406200.0
# ====================================================================================================
# Dataframe "UNH"
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2010-01-10  35.070000  35.470001  34.759998  35.430000  30.229097  6503500.0
# 1 2010-04-10  35.299999  35.299999  34.349998  34.540001  29.469746  5883300.0
# 2 2010-05-10  34.770000  35.130001  34.549999  35.070000  29.921938  6887400.0
# ====================================================================================================
# Dataframe "AAPL"
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2010-01-10  10.219643  10.235000  10.048214  10.090000   8.719163  448142800
# 1 2010-04-10  10.057143  10.103572   9.920357   9.951428   8.599421  435302000
# 2 2010-05-10  10.071428  10.337500  10.065000  10.319285   8.917298  501967200
# ====================================================================================================
# Dataframe "AMZN"
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2010-01-10  157.080002  157.440002  152.199997  153.710007  153.710007
# 1 2010-04-10  153.949997  155.960007  152.789993  155.389999  155.389999
# 2 2010-05-10  157.080002  161.210007  157.009995  160.869995  160.869995
#
#       Volume
# 0  8683400.0
# 1  5346500.0
# 2  5620000.0
# ====================================================================================================
# Dataframe "FB"
#         Date       Open   High        Low      Close  Adj Close       Volume
# 0 2012-05-18  42.049999  45.00  38.000000  38.230000  38.230000  573576400.0
# 1 2012-05-21  36.529999  36.66  33.000000  34.029999  34.029999  168192700.0
# 2 2012-05-22  32.610001  33.59  30.940001  31.000000  31.000000  101786600.0
# ====================================================================================================
# Dataframe "GOOG"
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2010-01-10  264.010437  264.319275  260.523499  261.828613  261.828613
# 1 2010-04-10  261.494843  263.138702  258.456238  260.199707  260.199707
# 2 2010-05-10  263.203461  268.991760  262.291870  268.110046  268.110046
#
#       Volume
# 0  4466600.0
# 1  3895400.0
# 2  7040400.0
# ====================================================================================================
# Dataframe "IBM"
#         Date        Open        High         Low       Close  Adj Close  \
# 0 2010-01-10  135.509995  136.279999  135.089996  135.639999  97.152512
# 1 2010-04-10  135.229996  135.919998  134.389999  135.250000  96.873192
# 2 2010-05-10  136.179993  137.899994  136.119995  137.660004  98.599335
#
#       Volume
# 0  5621200.0
# 1  4059900.0
# 2  6202500.0
# ====================================================================================================
# Dataframe "MSFT"
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2010-01-10  24.770000  24.820000  24.299999  24.379999  19.315863
# 1 2010-04-10  23.959999  23.990000  23.780001  23.910000  18.943493
# 2 2010-05-10  24.059999  24.450001  23.910000  24.350000  19.292101
#
#        Volume
# 0  62672300.0
# 1  98143400.0
# 2  78152900.0
# ====================================================================================================
# Dataframe "SP500"
#         Date         Open         High          Low        Close    Adj Close  \
# 0 2010-01-10  1143.489990  1150.300049  1139.420044  1146.239990  1146.239990
# 1 2010-04-10  1144.959961  1148.160034  1131.869995  1137.030029  1137.030029
# 2 2010-05-10  1140.680054  1162.760010  1140.680054  1160.750000  1160.750000
#
#        Volume
# 0  4298910000
# 1  3604110000
# 2  4068840000
# ====================================================================================================

# %% [markdown]
# Now that we have a brief grasp on our data, lets proceed to the next subtask which is data cleaning.

# %% [markdown]
# ### Sub-Task 2: Data Cleaning
#
# The first task will be to check the missing values/null values in our dataframes. Let's define a function that gives us the total number of null values in each dataframe.

# %%
def find_missing_values(stocks_dataframes_list:list[pd.DataFrame], dataframe_mapping=dataframe_mapping) -> list[tuple]:
    '''
    stocks_dataframes_list: List of Pandas DataFrame objects
    dataframe_mapping: A dictionary of dataframe mapping. By default, it takes the default mapping
    
    Returns: List of tuples of the dataframe name and corresponding number of missing values sorted in descending order
    of missing values
    '''
    
    temp_dict = {}
    for stock in stocks_dataframes_list:
        temp_dict[get_name_from_dataframe(stock, dataframe_mapping)] = int(stock.isnull().sum().sum())
    return sorted(temp_dict.items(), key = lambda x:x[1], reverse = True)

missing_values = find_missing_values(stocks_dataframes_list)
missing_values
# Out:
# [('BHC', 56),
#  ('JNJ', 56),
#  ('MRK', 56),
#  ('PFE', 56),
#  ('RHHBY', 56),
#  ('UNH', 56),
#  ('ALGT', 49),
#  ('ALK', 49),
#  ('DAL', 49),
#  ('HA', 49),
#  ('LUV', 49),
#  ('BCS', 49),
#  ('CS', 49),
#  ('DB', 49),
#  ('GS', 49),
#  ('MS', 49),
#  ('WFC', 49),
#  ('AMZN', 49),
#  ('FB', 49),
#  ('GOOG', 49),
#  ('IBM', 49),
#  ('MSFT', 49),
#  ('AAL', 0),
#  ('AAPL', 0),
#  ('SP500', 0)]

# %% [markdown]
# __Now that we have got the stock dataframes and their corresponding missing values, it's still hard to work with numbers. Humans can understand graphs and colours much better. So I will plot a bar chart of dataframes and the number of missing values.__

# %%
# Here I define x and y axis data to plot bar plot using seaborn
x = [i[0] for i in missing_values]
y = [i[1] for i in missing_values]

fig, ax = plt.subplots(figsize=(15, 12))
sns.barplot(x=x, y=y, ax=ax)
plt.show()

# %% [markdown]
# From the above plot, we can easily visualise the number of missing values in each of our dataframes. We also see that the last 3 dataframe [AAL, AAPL, SP500] does not have any missing values at all. Now let's proceed to handle these missing values in Pandas

# %% [markdown]
# There are many different ways to handle missing values. Some of the most common ways to handle missing values are:
# 1. Drop rows or columns that have a missing value
# 2. Fill with a constant value
# 3. Fill with an aggregated value
#
# Here I will be going with the first one. The other two options are not preferred as we do not want to introduce variations in data by imputation

# %% [markdown]
# __If all values in a particular row are null, then that row will not add any information to our data. So I will be dropping rows from the dataframe if all values in that row are empty.__

# %%
def drop_missing_values(stocks_dataframes_list:list[pd.DataFrame]) -> None:
    '''
    The function is used to drop all null values from the list of dataframes
    
    stocks_dataframes_list: List of dataframe objects
    
    Returns: None
    '''
    for stock in stocks_dataframes_list:
        rows = stock.shape[0]
        stock.dropna(how='all', inplace=True)
        print(f'Dropped {rows-stock.shape[0]} null rows from DataFrame "{get_name_from_dataframe(stock, dataframe_mapping)}"')

drop_missing_values(stocks_dataframes_list)
# Out:
# Dropped 0 null rows from DataFrame "AAL"
# Dropped 7 null rows from DataFrame "ALGT"
# Dropped 7 null rows from DataFrame "ALK"
# Dropped 7 null rows from DataFrame "DAL"
# Dropped 7 null rows from DataFrame "HA"
# Dropped 7 null rows from DataFrame "LUV"
# Dropped 7 null rows from DataFrame "BCS"
# Dropped 7 null rows from DataFrame "CS"
# Dropped 7 null rows from DataFrame "DB"
# Dropped 7 null rows from DataFrame "GS"
# Dropped 7 null rows from DataFrame "MS"
# Dropped 7 null rows from DataFrame "WFC"
# Dropped 8 null rows from DataFrame "BHC"
# Dropped 8 null rows from DataFrame "JNJ"
# Dropped 8 null rows from DataFrame "MRK"
# Dropped 8 null rows from DataFrame "PFE"
# Dropped 8 null rows from DataFrame "RHHBY"
# Dropped 8 null rows from DataFrame "UNH"
# Dropped 0 null rows from DataFrame "AAPL"
# Dropped 7 null rows from DataFrame "AMZN"
# Dropped 7 null rows from DataFrame "FB"
# Dropped 7 null rows from DataFrame "GOOG"
# Dropped 7 null rows from DataFrame "IBM"
# Dropped 7 null rows from DataFrame "MSFT"
# Dropped 0 null rows from DataFrame "SP500"

# %% [markdown]
# As we can see from the above ouput, we have dropped rows where all columns are null from our dataframes. Such rows do not add any value to our analysis. Now let's check the remaining number of null values from our dataframes by calling the function we defined earlier.

# %%
missing_values = find_missing_values(stocks_dataframes_list)
missing_values
# Out:
# [('AAL', 0),
#  ('ALGT', 0),
#  ('ALK', 0),
#  ('DAL', 0),
#  ('HA', 0),
#  ('LUV', 0),
#  ('BCS', 0),
#  ('CS', 0),
#  ('DB', 0),
#  ('GS', 0),
#  ('MS', 0),
#  ('WFC', 0),
#  ('BHC', 0),
#  ('JNJ', 0),
#  ('MRK', 0),
#  ('PFE', 0),
#  ('RHHBY', 0),
#  ('UNH', 0),
#  ('AAPL', 0),
#  ('AMZN', 0),
#  ('FB', 0),
#  ('GOOG', 0),
#  ('IBM', 0),
#  ('MSFT', 0),
#  ('SP500', 0)]

# %% [markdown]
# __As we can see from the above output, we have removed all null values from our dataframes and we can now proceed to the subsequent subtasks__

# %% [markdown]
# ### Sub-Task 2: Data Merging
#
# The entire data must be merged into a single dataframe with only the required columns. Most importantly, you must ensure that you can identify the company and the industry from the collated data for company-specific and industry analysis.
#
# For the above subtask, I performed the following steps:
# 1. Filter out the required columns and discard the rest
# 2. Prefix company name to those columns so that we can identify the company and perform analysis easier by merging into a single dataframe
# 3. Merge all dataframes to a single dataframe
#
# Note - All above steps will be implemented as functions to improve code reusability and readabilty

# %%
## The columns which I will be using for my analysis
required_columns = ['Date', 'Open', 'Close', 'Volume']
exclude_columns = ['Date']

## New column mapping dictionary
def map_company_name_to_columns(stock:pd.DataFrame, exclude_columns:list):
    '''
    This is a helper function to generate dictionary mappings of old and new column names
    
    stock: DataFrame object
    exclude_columns: List of column names that should be excluded from prefixing
    
    Returns: A dictionary mapping with old column name as key and new column name as value. The new column name will
    have the company name prefixed to it. Date column will not be mapped and reatined as such
    '''
    return {col:get_name_from_dataframe(stock, final_dataframe_mapping)+'_'+col for col in stock if col not in exclude_columns}

## Function to keep only the required columns and discard the rest
def filter_columns_dataframe(stocks_dataframes_list:list[pd.DataFrame], required_columns:list) -> list[pd.DataFrame]:
    '''
    This function retains the given set of columns and discards the rest
    
    stocks_dataframes_list: List of dataframe objects
    required_columns: List of required columns that should be kept
    
    Returns: An updated list of dataframe objects
             An updated mapping dictionary of dataframe company names and their respective dataframe objects
    '''
    
    final_dataframe_mapping = {}
    final_stocks_dataframes_list = []
    for idx,stock in enumerate(stocks_dataframes_list):
        name_of_dataframe = get_name_from_dataframe(stock, dataframe_mapping)
        stock = stock[required_columns]
        final_dataframe_mapping[name_of_dataframe] = stock
        final_stocks_dataframes_list.append(stock)
    print('Step 1 (Completed): All required columns are persisted to the dataframes')
    return final_stocks_dataframes_list, final_dataframe_mapping

def prefix_company_name_to_dataframe(final_stocks_dataframes_list:list[pd.DataFrame], exclude_columns:list) -> None:
    '''
    This function prefixes the company name to all the columns except the excluded column
    
    final_stocks_dataframes_list: An updated list of dataframe objectss
    exclude_columns: List of column names that should be excluded from prefixing
    
    Returns None
    '''
    for stock in final_stocks_dataframes_list:
        new_company_mapping_dict = map_company_name_to_columns(stock, exclude_columns)
        stock.rename(new_company_mapping_dict, inplace=True, axis='columns')
    print('Step 2 (Completed): Company name has been prefixed in all the columns for each company dataframe')

## Now I will call all the defined functions in the mentioned order

# Step 1: Filter required columns from the dataframes and discard the rest
final_stocks_dataframes_list, final_dataframe_mapping = filter_columns_dataframe(stocks_dataframes_list, required_columns)

# Step 2: Prefix company name to call the columns to make datafarmes ready for merging
prefix_company_name_to_dataframe(final_stocks_dataframes_list, exclude_columns)
# Out:
# Step 1 (Completed): All required columns are persisted to the dataframes
# Step 2 (Completed): Company name has been prefixed in all the columns for each company dataframe
# D:\Softwares\Anaconda\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %% [markdown]
# Now let's inspect the dataframes to check the renamed columns

# %%
for stock in final_stocks_dataframes_list:
    print(f'Dataframe "{get_name_from_dataframe(stock, final_dataframe_mapping)}"')
    print(stock.head(3))
    print('='*100)
# Out:
# Dataframe "AAL"
#         Date  AAL_Open  AAL_Close  AAL_Volume
# 0 2010-01-10      9.29       9.29     3603800
# 1 2010-04-10      9.24       9.12     3856800
# 2 2010-05-10      9.27       9.23     3896600
# ====================================================================================================
# Dataframe "ALGT"
#         Date  ALGT_Open  ALGT_Close  ALGT_Volume
# 0 2010-01-10  42.779999   43.230000     159100.0
# 1 2010-04-10  43.250000   41.590000     189700.0
# 2 2010-05-10  41.779999   42.099998     175000.0
# ====================================================================================================
# Dataframe "ALK"
#         Date  ALK_Open  ALK_Close  ALK_Volume
# 0 2010-01-10   12.9325    12.4475   1663600.0
# 1 2010-04-10   12.4300    12.1425   1512400.0
# 2 2010-05-10   12.2600    12.2150   2567200.0
# ====================================================================================================
# Dataframe "DAL"
#         Date  DAL_Open  DAL_Close  DAL_Volume
# 0 2010-01-10     11.75      12.01   9094900.0
# 1 2010-04-10     11.70      11.51   7916400.0
# 2 2010-05-10     11.57      11.83  12624100.0
# ====================================================================================================
# Dataframe "HA"
#         Date  HA_Open  HA_Close  HA_Volume
# 0 2010-01-10     6.02      5.96   645400.0
# 1 2010-04-10     5.96      5.75   618900.0
# 2 2010-05-10     5.82      5.85   534800.0
# ====================================================================================================
# Dataframe "LUV"
#         Date  LUV_Open  LUV_Close  LUV_Volume
# 0 2010-01-10     13.23      12.94   5722500.0
# 1 2010-04-10     12.92      12.82   6537700.0
# 2 2010-05-10     12.97      13.02   8060000.0
# ====================================================================================================
# Dataframe "BCS"
#         Date   BCS_Open  BCS_Close  BCS_Volume
# 0 2010-04-01  16.709677  16.894009   2144300.0
# 1 2010-05-01  17.631336  17.824884   2710600.0
# 2 2010-06-01  17.797235  18.129032   2124100.0
# ====================================================================================================
# Dataframe "CS"
#         Date    CS_Open   CS_Close  CS_Volume
# 0 2010-04-01  49.902344  50.771484   734200.0
# 1 2010-05-01  51.250000  51.191406   447700.0
# 2 2010-06-01  50.224609  50.478516   751200.0
# ====================================================================================================
# Dataframe "DB"
#         Date    DB_Open   DB_Close  DB_Volume
# 0 2010-04-01  69.103050  69.875954   469500.0
# 1 2010-05-01  71.412216  71.211830   503300.0
# 2 2010-06-01  69.847328  69.980919   495000.0
# ====================================================================================================
# Dataframe "GS"
#         Date     GS_Open    GS_Close   GS_Volume
# 0 2010-04-01  170.050003  173.080002   9135000.0
# 1 2010-05-01  173.000000  176.139999  11659400.0
# 2 2010-06-01  175.380005  174.259995   7381100.0
# ====================================================================================================
# Dataframe "MS"
#         Date    MS_Open   MS_Close   MS_Volume
# 0 2010-04-01  30.700001  30.910000  20371000.0
# 1 2010-05-01  31.010000  32.040001  22523400.0
# 2 2010-06-01  31.969999  32.450001  17028500.0
# ====================================================================================================
# Dataframe "WFC"
#         Date   WFC_Open  WFC_Close  WFC_Volume
# 0 2010-04-01  27.020000  27.320000  39335700.0
# 1 2010-05-01  27.270000  28.070000  55416000.0
# 2 2010-06-01  28.030001  28.110001  33237000.0
# ====================================================================================================
# Dataframe "BHC"
#         Date   BHC_Open  BHC_Close  BHC_Volume
# 0 2010-01-10  25.120001  25.750000   5778700.0
# 1 2010-04-10  25.750000  25.870001   4187200.0
# 2 2010-05-10  26.040001  26.299999   4610300.0
# ====================================================================================================
# Dataframe "JNJ"
#         Date   JNJ_Open  JNJ_Close  JNJ_Volume
# 0 2010-01-10  62.090000  61.750000   9773200.0
# 1 2010-04-10  61.540001  61.669998   8703600.0
# 2 2010-05-10  62.080002  62.799999  12439400.0
# ====================================================================================================
# Dataframe "MRK"
#         Date   MRK_Open  MRK_Close  MRK_Volume
# 0 2010-01-10  36.759998  36.599998  11741900.0
# 1 2010-04-10  36.490002  36.520000   9234900.0
# 2 2010-05-10  36.860001  37.020000  10669200.0
# ====================================================================================================
# Dataframe "PFE"
#         Date   PFE_Open  PFE_Close  PFE_Volume
# 0 2010-01-10  17.250000      17.18  35520800.0
# 1 2010-04-10  17.100000      16.90  40665800.0
# 2 2010-05-10  17.110001      17.23  44694000.0
# ====================================================================================================
# Dataframe "RHHBY"
#         Date  RHHBY_Open  RHHBY_Close  RHHBY_Volume
# 0 2010-01-10   17.200001    17.389999     1405600.0
# 1 2010-04-10   17.305000    17.275000      453600.0
# 2 2010-05-10   17.575001    17.799999     1406200.0
# ====================================================================================================
# Dataframe "UNH"
#         Date   UNH_Open  UNH_Close  UNH_Volume
# 0 2010-01-10  35.070000  35.430000   6503500.0
# 1 2010-04-10  35.299999  34.540001   5883300.0
# 2 2010-05-10  34.770000  35.070000   6887400.0
# ====================================================================================================
# Dataframe "AAPL"
#         Date  AAPL_Open  AAPL_Close  AAPL_Volume
# 0 2010-01-10  10.219643   10.090000    448142800
# 1 2010-04-10  10.057143    9.951428    435302000
# 2 2010-05-10  10.071428   10.319285    501967200
# ====================================================================================================
# Dataframe "AMZN"
#         Date   AMZN_Open  AMZN_Close  AMZN_Volume
# 0 2010-01-10  157.080002  153.710007    8683400.0
# 1 2010-04-10  153.949997  155.389999    5346500.0
# 2 2010-05-10  157.080002  160.869995    5620000.0
# ====================================================================================================
# Dataframe "FB"
#         Date    FB_Open   FB_Close    FB_Volume
# 0 2012-05-18  42.049999  38.230000  573576400.0
# 1 2012-05-21  36.529999  34.029999  168192700.0
# 2 2012-05-22  32.610001  31.000000  101786600.0
# ====================================================================================================
# Dataframe "GOOG"
#         Date   GOOG_Open  GOOG_Close  GOOG_Volume
# 0 2010-01-10  264.010437  261.828613    4466600.0
# 1 2010-04-10  261.494843  260.199707    3895400.0
# 2 2010-05-10  263.203461  268.110046    7040400.0
# ====================================================================================================
# Dataframe "IBM"
#         Date    IBM_Open   IBM_Close  IBM_Volume
# 0 2010-01-10  135.509995  135.639999   5621200.0
# 1 2010-04-10  135.229996  135.250000   4059900.0
# 2 2010-05-10  136.179993  137.660004   6202500.0
# ====================================================================================================
# Dataframe "MSFT"
#         Date  MSFT_Open  MSFT_Close  MSFT_Volume
# 0 2010-01-10  24.770000   24.379999   62672300.0
# 1 2010-04-10  23.959999   23.910000   98143400.0
# 2 2010-05-10  24.059999   24.350000   78152900.0
# ====================================================================================================
# Dataframe "SP500"
#         Date   SP500_Open  SP500_Close  SP500_Volume
# 0 2010-01-10  1143.489990  1146.239990    4298910000
# 1 2010-04-10  1144.959961  1137.030029    3604110000
# 2 2010-05-10  1140.680054  1160.750000    4068840000
# ====================================================================================================

# %% [markdown]
# __As you can see from the above data, the column names looks good. Now we can proceed to step 3 to merge all dataframes to a single dataframe.__

# %% [markdown]
# To merge the dataframes to a single dataframe, I will be using an inner join and will use 'Date' column as a key to join. Now let's define a function to accomplish this. The function will need two inputs:
# 1. An updated list of dataframe objects - We found this in the earlier cells and assigned the list to variable name 'final_stocks_dataframes_list'.
# 2. strategy - The type of join to perform

# %%
def merge_all_dataframes(final_stocks_dataframes_list:list[pd.DataFrame], strategy:str) -> pd.DataFrame:
    '''
    final_stocks_dataframes_list: An updated list of dataframe objects to be merged to a single dataframe
    strategy: The type of join to perform
    
    Returns: A single merged dataframe
    '''
    left_dataframe = final_stocks_dataframes_list[0]
    for stock in final_stocks_dataframes_list[1:]:
        right_dataframe = stock
        left_dataframe = pd.merge(left=left_dataframe, right=right_dataframe, how=strategy, on='Date')
    return left_dataframe

final_stocks_df = merge_all_dataframes(final_stocks_dataframes_list, 'inner')
final_stocks_df.head(3)
# Out:
#         Date  AAL_Open  AAL_Close  AAL_Volume  ALGT_Open  ALGT_Close  \
# 0 2012-05-18     10.23      10.06    10813400  61.990002   62.310001
# 1 2012-05-21     10.07      10.71     8290100  62.209999   62.660000
# 2 2012-05-22     10.75      10.62     6227400  62.509998   62.349998
#
#    ALGT_Volume   ALK_Open  ALK_Close  ALK_Volume  ...  GOOG_Volume  \
# 0     167000.0  16.070000  16.170000   2745800.0  ...   11991700.0
# 1     150600.0  16.165001  16.379999   1361600.0  ...    6173800.0
# 2     125500.0  16.410000  16.225000   1003600.0  ...    6126600.0
#
#      IBM_Open   IBM_Close  IBM_Volume  MSFT_Open  MSFT_Close  MSFT_Volume  \
# 0  198.779999  195.880005   5737100.0  29.790001       29.27   56205300.0
# 1  195.979996  197.759995   3831700.0  29.100000       29.75   38787900.0
# 2  198.039993  196.820007   3567100.0  29.690001       29.76   39504900.0
#
#     SP500_Open  SP500_Close  SP500_Volume
# 0  1305.050049  1295.219971    4512470000
# 1  1295.729980  1315.989990    3786750000
# 2  1316.089966  1316.630005    4123680000
#
# [3 rows x 76 columns]

# %% [markdown]
# Let's assert the number of columns of our final dataframe.
# Since we are retaining 4 columns with 'Date' column as key, the total number of columns will be 3*No of dataframes + 1 (Date column)

# %%
expected_number_columns = 3*len(final_stocks_dataframes_list) + 1

try:
    assert final_stocks_df.shape[1] == expected_number_columns
    print('Dataframe rows has been asserted successfully')
except AssertionError as error:
    print('Assertion failed!!!')
# Out:
# Dataframe rows has been asserted successfully

# %% [markdown]
# __Now that we have merged all dataframes to a single dataframe 'final_stocks_df', let's inspect the dataframe further to get a better grasp on the data__

# %%
## Let's check the dataframe and its schema

final_stocks_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2106 entries, 0 to 2105
# Data columns (total 76 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          2106 non-null   datetime64[ns]
#  1   AAL_Open      2106 non-null   float64
#  2   AAL_Close     2106 non-null   float64
#  3   AAL_Volume    2106 non-null   int64
#  4   ALGT_Open     2106 non-null   float64
#  5   ALGT_Close    2106 non-null   float64
#  6   ALGT_Volume   2106 non-null   float64
#  7   ALK_Open      2106 non-null   float64
#  8   ALK_Close     2106 non-null   float64
#  9   ALK_Volume    2106 non-null   float64
#  10  DAL_Open      2106 non-null   float64
#  11  DAL_Close     2106 non-null   float64
#  12  DAL_Volume    2106 non-null   float64
#  13  HA_Open       2106 non-null   float64
#  14  HA_Close      2106 non-null   float64
#  15  HA_Volume     2106 non-null   float64
#  16  LUV_Open      2106 non-null   float64
#  17  LUV_Close     2106 non-null   float64
#  18  LUV_Volume    2106 non-null   float64
#  19  BCS_Open      2106 non-null   float64
#  20  BCS_Close     2106 non-null   float64
#  21  BCS_Volume    2106 non-null   float64
#  22  CS_Open       2106 non-null   float64
#  23  CS_Close      2106 non-null   float64
#  24  CS_Volume     2106 non-null   float64
#  25  DB_Open       2106 non-null   float64
#  26  DB_Close      2106 non-null   float64
#  27  DB_Volume     2106 non-null   float64
#  28  GS_Open       2106 non-null   float64
#  29  GS_Close      2106 non-null   float64
#  30  GS_Volume     2106 non-null   float64
#  31  MS_Open       2106 non-null   float64
#  32  MS_Close      2106 non-null   float64
#  33  MS_Volume     2106 non-null   float64
#  34  WFC_Open      2106 non-null   float64
#  35  WFC_Close     2106 non-null   float64
#  36  WFC_Volume    2106 non-null   float64
#  37  BHC_Open      2106 non-null   float64
#  38  BHC_Close     2106 non-null   float64
#  39  BHC_Volume    2106 non-null   float64
#  40  JNJ_Open      2106 non-null   float64
#  41  JNJ_Close     2106 non-null   float64
#  42  JNJ_Volume    2106 non-null   float64
#  43  MRK_Open      2106 non-null   float64
#  44  MRK_Close     2106 non-null   float64
#  45  MRK_Volume    2106 non-null   float64
#  46  PFE_Open      2106 non-null   float64
#  47  PFE_Close     2106 non-null   float64
#  48  PFE_Volume    2106 non-null   float64
#  49  RHHBY_Open    2106 non-null   float64
#  50  RHHBY_Close   2106 non-null   float64
#  51  RHHBY_Volume  2106 non-null   float64
#  52  UNH_Open      2106 non-null   float64
#  53  UNH_Close     2106 non-null   float64
#  54  UNH_Volume    2106 non-null   float64
#  55  AAPL_Open     2106 non-null   float64
#  56  AAPL_Close    2106 non-null   float64
#  57  AAPL_Volume   2106 non-null   int64
#  58  AMZN_Open     2106 non-null   float64
#  59  AMZN_Close    2106 non-null   float64
#  60  AMZN_Volume   2106 non-null   float64
#  61  FB_Open       2106 non-null   float64
#  62  FB_Close      2106 non-null   float64
#  63  FB_Volume     2106 non-null   float64
#  64  GOOG_Open     2106 non-null   float64
#  65  GOOG_Close    2106 non-null   float64
#  66  GOOG_Volume   2106 non-null   float64
#  67  IBM_Open      2106 non-null   float64
#  68  IBM_Close     2106 non-null   float64
#  69  IBM_Volume    2106 non-null   float64
#  70  MSFT_Open     2106 non-null   float64
#  71  MSFT_Close    2106 non-null   float64
#  72  MSFT_Volume   2106 non-null   float64
#  73  SP500_Open    2106 non-null   float64
#  74  SP500_Close   2106 non-null   float64
#  75  SP500_Volume  2106 non-null   int64
# dtypes: datetime64[ns](1), float64(72), int64(3)
# memory usage: 1.2 MB

# %% [markdown]
# __As we can see above, the data in our final datafraem looks good. All the datatypes of the columns are also accurate.
# Let's also check for any null values using our defined method__

# %%
missing_values = final_stocks_df.isnull().sum()
missing_values
# Out:
# Date            0
# AAL_Open        0
# AAL_Close       0
# AAL_Volume      0
# ALGT_Open       0
#                ..
# MSFT_Close      0
# MSFT_Volume     0
# SP500_Open      0
# SP500_Close     0
# SP500_Volume    0
# Length: 76, dtype: int64

# %% [markdown]
# __Now our data cleaning part is complete. Let's proceed with the next task 'Data Exploration'__
